# %% [markdown]
# <a href="https://colab.research.google.com/github/AakankshaDhidhi/Myrepository/blob/main/replacing_vgg_with_RESnetnovcode_batch_size64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction and data collection**

# %%
#importing packages
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import json
from google.colab import drive

# %%
import tensorflow as tf

# We'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
#import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import re
import numpy as np
import pandas as pd
import os
import time
import json
import collections
import operator
from glob import glob
from PIL import Image
import pickle
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from tensorflow import reshape
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, Embedding, LSTM, Activation,ZeroPadding1D,Conv1D

print("Done imports")
# Out:
# Done imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %% [markdown]
# **Mounting drive for saving data**

# %%
drive.mount('/content/drive/', force_remount=True) #mouting the drive
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Downloading COCO images**

# %% [markdown]
# **Downloading VQA Questions**

# %%
annotation_zip = tf.keras.utils.get_file('captions.zip',cache_subdir=os.path.abspath('.'),origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',extract = True)

annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'

name_of_zip = 'train2014.zip'
if not os.path.exists(os.path.abspath('.')+'/' + name_of_zip):
  image_zip = tf.keras.utils.get_file(name_of_zip,cache_subdir=os.path.abspath('.'),origin='http://images.cocodataset.org/zips/train2014.zip',extract=True)
  PATH = os.path.dirname(image_zip)+'/train2014'
else:
  PATH = os.path.abspath('.')+'/train2014'
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 8s 0us/step
# 252887040/252872794 [==============================] - 8s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 382s 0us/step
# 13510582272/13510573713 [==============================] - 382s 0us/step

# %%
print(PATH)
#!wget https://s3.amazonaws.com/cvmlp/vqs/mscoco/vqa/v2_Questions_Train_mscoco.zip
#!unzip -a v2_Questions_Train_mscoco.zip
# !wget https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip
# !unzip -a v2_Annotations_Train_mscoco.zip
# !wget https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip
# !unzip -a v2_Questions_Train_mscoco.zip
# Out:
# /content/train2014
# --2022-05-23 12:00:17--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.145.157
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.145.157|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21708861 (21M) [application/zip]
# Saving to: ‘v2_Annotations_Train_mscoco.zip’
#
# v2_Annotations_Trai 100%[===================>]  20.70M  18.6MB/s    in 1.1s
#
# 2022-05-23 12:00:19 (18.6 MB/s) - ‘v2_Annotations_Train_mscoco.zip’ saved [21708861/21708861]
#
# Archive:  v2_Annotations_Train_mscoco.zip
#   inflating: v2_mscoco_train2014_annotations.json  [text]
# --2022-05-23 12:00:22--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.98.29
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.98.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7239401 (6.9M) [application/zip]
# Saving to: ‘v2_Questions_Train_mscoco.zip’
#
# v2_Questions_Train_ 100%[===================>]   6.90M  10.1MB/s    in 0.7s
#
# 2022-05-23 12:00:23 (10.1 MB/s) - ‘v2_Questions_Train_mscoco.zip’ saved [7239401/7239401]
#
# Archive:  v2_Questions_Train_mscoco.zip
#   inflating: v2_OpenEnded_mscoco_train2014_questions.json  [text]

# %%
# read the json file
question_file_path = 'v2_OpenEnded_mscoco_train2014_questions.json'
with open(question_file_path, 'r') as f:
    questions = json.load(f)

print("Total Number Questions is : ",len(questions['questions']))
# Out:
# Total Number Questions is :  443757

# %% [markdown]
# **Added code from separate image model**

# %%
#Storing the captions and image file name in vectors
import collections
import operator

annotation_file = 'v2_mscoco_train2014_annotations.json'

with open(annotation_file,'r') as f:
  annotations = json.load(f)



all_answers = []
all_answers_qids = []
all_img_name_vector = []

for annot in annotations['annotations']:
  #print(annot)
  ans_dic = collections.defaultdict(int)
  for each in annot['answers']:
    diffans = each['answer']
    if diffans in ans_dic:
      #print(each['answer_confidence'])
      if each['answer_confidence']=='yes':
        ans_dic[diffans]+=4
      if each['answer_confidence']=='maybe':
        ans_dic[diffans]+=2
      if each['answer_confidence']=='no':
        ans_dic[diffans]+=1
    else:
      if each['answer_confidence']=='yes':
        ans_dic[diffans]+=4
      if each['answer_confidence']=='maybe':
        ans_dic[diffans]+=2
      if each['answer_confidence']=='no':
        ans_dic[diffans]+=1

  #print(ans_dic)
  most_fav = max(ans_dic.items(),key=operator.itemgetter(1))[0]
  #print(most_fav)
  caption = '<start>' + most_fav + '<end>'  #each['answer']

  image_id = annot['image_id']
  question_id = annot['question_id']
  full_coco_image_path = PATH  + '/COCO_train2014_' + '%012d.jpg' %(image_id)

  all_img_name_vector.append(full_coco_image_path)
  all_answers.append(caption)
  all_answers_qids.append(question_id)

# %%
all_questions = []
question_ids = []
all_img_name_vector_2 = []


for annot in questions['questions']:
  caption = '<start>' + annot['question'] + '<end>'
  image_id = annot['image_id']
  full_coco_image_path = PATH + '/COCO_train2014_' + '%012d.jpg' %(image_id)
  
  all_img_name_vector_2.append(full_coco_image_path)
  all_questions.append(caption)
  #print(all_questions)
  question_ids.append(annot['question_id'])

# %%
print(questions['questions'][np.random.randint(0,443757)])#new ms coco code
# Out:
# {'image_id': 22958, 'question': 'What number is shown on the watch next FRI?', 'question_id': 22958005}

# %%
#Taken from separate image model
print(len(all_img_name_vector),len(all_answers),len(all_answers_qids))
print(all_img_name_vector[10:15],all_answers[10:15],all_answers_qids[10:15])
print(len(all_img_name_vector_2),len(all_questions),len(question_ids))
print(all_img_name_vector_2[10:15],all_questions[10:15],question_ids[10:15])
# Out:
# 443757 443757 443757
# ['/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393223.jpg', '/content/train2014/COCO_train2014_000000393223.jpg'] ['<start>yes<end>', '<start>yes<end>', '<start>contrail<end>', '<start>yes<end>', '<start>white and purple<end>'] [393221000, 393221001, 393221002, 393223000, 393223001]
# 443757 443757 443757
# ['/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393223.jpg', '/content/train2014/COCO_train2014_000000393223.jpg'] ['<start>Is the sky blue?<end>', '<start>Is there snow on the mountains?<end>', '<start>What is the white streak?<end>', '<start>Is the window open?<end>', '<start>What color is the toothbrush?<end>'] [393221000, 393221001, 393221002, 393223000, 393223001]

# %% [markdown]
# **Shuffling all questions and answers(taken from separate image model)**

# %%
train_answers,train_questions,img_name_vector = shuffle(all_answers,all_questions,all_img_name_vector,random_state=1)
#train_answers,train_questions,img_name_vector = (all_answers,all_questions,all_img_name_vector)
num_examples=50

train_answers = train_answers[:num_examples]
train_questions = train_questions[:num_examples]
img_name_vector =img_name_vector[:num_examples]

print(img_name_vector[0],train_questions[0],train_answers[0])
print(len(img_name_vector),len(train_questions),len(train_answers))
# Out:
# /content/train2014/COCO_train2014_000000573744.jpg <start>Is this a happy animal?<end> <start>yes<end>
# 50 50 50

# %% [markdown]
# **Downloading VQA Annotations**

# %%
annotation_file_path = 'v2_mscoco_train2014_annotations.json'
with open(annotation_file_path, 'r') as f:
    annotations = json.load(f)

# %%
annotations['annotations'][np.random.randint(0,443757)]
# Out:
# {'answer_type': 'yes/no',
#  'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#   {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#  'image_id': 342495,
#  'multiple_choice_answer': 'no',
#  'question_id': 342495000,
#  'question_type': 'is he'}

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Data preprocessing**

# %%
#importing packages
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
import json
import seaborn as sns
import tensorflow as tf

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from wordcloud import WordCloud
from google.colab import drive
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Variables**

# %% [markdown]
# **DATA TRANSFORMATION**
# LOADING QUESTIONS AND ANSWERS

# %%
with open(question_file_path, 'r') as f:
    questions = json.load(f)
    questions = questions["questions"]

with open(annotation_file_path, 'r') as f:
    annotations = json.load(f)
    annotations = annotations["annotations"]

# %%
print("Total Number Questions is : ",len(questions))
# Out:
# Total Number Questions is :  443757

# %%
questions_df = pd.DataFrame(questions).sample(n=10000)
#questions_df = pd.DataFrame(questions)
#ques_samp = questions_df.sample(n=100)
#ques_samp.head(5)

questions_df.head(5)
# Out:
#         image_id                                     question  question_id
# 436967    260110                        What are they eating?    260110025
# 207690    228244                       Can you see mountains?    228244006
# 159010     44922                   How many plates are there?     44922002
# 414833    384389                 Has this person been skiing?    384389002
# 179885    298479  Does the cat on the right have sleepy eyes?    298479002

# %%
annotations_df = pd.DataFrame(annotations).sample(n=10000)
#annotations_df = pd.DataFrame(annotations)
#annot_samp = annotations_df.sample(n=100)
#annot_samp.head(5)
annotations_df.head(5)
print(len(annotations_df))
# Out:
# 10000

# %% [markdown]
# **MERGING QUESTIONS AND ANNOTATIONS**

# %%
data = pd.merge(questions_df,annotations_df,  how='inner', left_on=['image_id','question_id'], right_on = ['image_id','question_id'])
#data_samp = pd.merge(ques_samp,annot_samp,  how='inner', left_on=['image_id','question_id'], right_on = ['image_id','question_id'])
print(len(data))
# Out:
# 234

# %%
data.head(5)
#data_samp.head(5)
# Out:
#    image_id                        question  question_id question_type  \
# 0    269126     How was this picture taken?    269126003           how
# 1     75521               Is the room dark?     75521023        is the
# 2    367125            Is this boat at sea?    367125002       is this
# 3    149812  What are these man's emotions?    149812005      what are
# 4    103447       What kind of cat is this?    103447003  what kind of
#
#   multiple_choice_answer                                            answers  \
# 0            with camera  [{'answer': 'security camera', 'answer_confide...
# 1                     no  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 2                     no  [{'answer': 'no', 'answer_confidence': 'yes', ...
# 3            competitive  [{'answer': 'concentration', 'answer_confidenc...
# 4                 calico  [{'answer': 'calico', 'answer_confidence': 'ma...
#
#   answer_type
# 0       other
# 1      yes/no
# 2      yes/no
# 3       other
# 4       other

# %%
#currentDirectory = "/content/drive/My Drive/pcase_study_2/"
#os.chdir(currentDirectory)
#currentDirectory = ""
#dataDirectory = currentDirectory + "data/"
#imageDirectory = dataDirectory + "train2014/"
imageDirectory = '/content/train2014'
#question_file_path = dataDirectory + 'v2_OpenEnded_mscoco_train2014_questions.json'
question_file_path = '/content/v2_OpenEnded_mscoco_train2014_questions.json'
#annotation_file_path = dataDirectory + 'v2_mscoco_train2014_annotations.json'
annotation_file_path = '/content/v2_mscoco_train2014_annotations.json'

# %%
imageDirectory = '/content/train2014'
os.chdir(imageDirectory)
imageDirectory = ""

# %%
index = np.random.randint(0,len(data))#263115

img_path =  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (data['image_id'][index])
img=mpimg.imread(img_path)
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()
print("*"*50)
print("Question : " ,data['question'][index])
print("*"*50)
print("Answer : ", data['multiple_choice_answer'][index])

print(img.shape)
# Out:
# **************************************************
# Question :  Are this tracks rails?
# **************************************************
# Answer :  yes
# (427, 640, 3)

# %% [markdown]
# **IMAGES**

# %%
aggregations = {'question': 'count'}
temp = pd.DataFrame(data.groupby(['image_id'],as_index=False).agg(aggregations))
#temp.set_index('image_id', inplace=True)

print(temp)
print(len(temp))
num_of_ques_in_image = temp['question'].values
print("Max number of questions on a image",max(num_of_ques_in_image))
print("Min number of questions on a image",min(num_of_ques_in_image))
print("Mean of questions on a image",np.mean(num_of_ques_in_image))

ax = sns.boxplot(y = 'question', data = temp) 
plt.title("boxplot of Number of questions on a iage")
plt.show()
# Out:
#      image_id  question
# 0        3293         1
# 1        9658         1
# 2       12098         1
# 3       12138         1
# 4       12766         1
# ..        ...       ...
# 229    565401         1
# 230    565641         1
# 231    569520         1
# 232    569742         1
# 233    579045         1
#
# [234 rows x 2 columns]
# 234
# Max number of questions on a image 1
# Min number of questions on a image 1
# Mean of questions on a image 1.0

# %% [markdown]
# **IMAGES THAT HAVE MAXIMUM NUMBER OF QUESTIONS**

# %% [markdown]
# **Duplicate questions on same image**

# %%
aggregations = {'question_id':'count', 'multiple_choice_answer': lambda x: " || ".join(x)}
temp = pd.DataFrame(data.groupby(['image_id','question'],as_index=False).agg(aggregations)).rename(columns={'question_id':'count'})
temp = temp[temp['count']>1]
temp
# Out:
# Empty DataFrame
# Columns: [image_id, question, count, multiple_choice_answer]
# Index: []

# %% [markdown]
# **Question type**

# %%
data.question_type.unique()
# Out:
# array(['how', 'is the', 'is this', 'what are', 'what kind of', 'what',
#        'are there', 'where is the', 'what sport is', 'what type of',
#        'who is', 'what number is', 'is the person', 'what is the name',
#        'what color are the', 'what color is the', 'is it', 'what is the',
#        'how many', 'what room is', 'what is the man', 'is he', 'does the',
#        'is there a', 'are these', 'is this a', 'what is', 'what are the',
#        'how many people are', 'none of the above', 'is this person',
#        'is there', 'are', 'is this an', 'what is on the', 'why',
#        'are the', 'are they', 'what is in the', 'what is the woman',
#        'where are the', 'what color', 'is that a', 'could', 'is', 'was',
#        'can you', 'do you', 'what time', 'does this', 'what is this',
#        'what does the', 'is the woman', 'is the man', 'why is the',
#        'are there any'], dtype=object)

# %%
print("Number of unique Question type in dataset : ",len(data.question_type.unique()))
# Out:
# Number of unique Question type in dataset :  56

# %%
def getFrequnctDict(data,column,isJoin=False):
    column_frequency = {}

    for _row in data[column]:
        if isJoin:
            _row = "_".join(_row.split())
        if(column_frequency.get(_row,-1) > 0):
            column_frequency[_row] += 1
        else:
            column_frequency[_row] = 1

    return column_frequency

def lineChart(data,column,top=20,isJoin=False):
    column_frequncy = getFrequnctDict(data,column,isJoin)
    sort_column_frequncy = sorted(list(column_frequncy.items()),key = lambda x: x[1],reverse=True)
    total_samples =  len(data)

    plt.plot([x[1]for x in sort_column_frequncy[:top]])
    i=np.arange(top)
    plt.title("Frequency of top " + str(top) + " " + column )
    plt.xlabel("Tags")
    plt.ylabel("Counts")
    plt.xticks(i,[x[0] for x in sort_column_frequncy[:top]])
    plt.xticks(rotation=90)
    plt.show()
    return sort_column_frequncy

def plotWordCloud(data,column,isJoin=False):
    column_frequncy = getFrequnctDict(data,column,isJoin)
    #https://www.geeksforgeeks.org/generating-word-cloud-python/
    wordcloud = WordCloud(width = 800, height = 800, 
                    background_color ='white', 
                    stopwords = None, 
                    min_font_size = 10).generate_from_frequencies(column_frequncy)
    # plot the WordCloud image     
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title("WordCloud on "+ column)  
    plt.show()

# %%
plotWordCloud(data, 'question_type')
question_type_frequncy = lineChart(data, 'question_type', top = 30)

# %%
for _type,_count in question_type_frequncy[:10]:
    print("Percentage of '" + _type + "' Type of Questions in Dataset is ", str(100*_count/len(data)))
# Out:
# Percentage of 'what' Type of Questions in Dataset is  10.683760683760683
# Percentage of 'is the' Type of Questions in Dataset is  9.401709401709402
# Percentage of 'what color is the' Type of Questions in Dataset is  5.982905982905983
# Percentage of 'how many' Type of Questions in Dataset is  5.555555555555555
# Percentage of 'what is the' Type of Questions in Dataset is  5.128205128205129
# Percentage of 'what kind of' Type of Questions in Dataset is  4.700854700854701
# Percentage of 'what is' Type of Questions in Dataset is  3.8461538461538463
# Percentage of 'is there a' Type of Questions in Dataset is  2.9914529914529915
# Percentage of 'none of the above' Type of Questions in Dataset is  2.9914529914529915
# Percentage of 'is this' Type of Questions in Dataset is  2.5641025641025643

# %% [markdown]
# **ANSWERS**

# %%
data['answer_type'].unique()
# Out:
# array(['other', 'yes/no', 'number'], dtype=object)

# %%
answer_type_frequncy = lineChart(data, 'answer_type', top = 3)

# %%
for _type,_count in answer_type_frequncy:
    print("Percentage of '" + _type + "' Type of Answers in Dataset is ", str(100*_count/len(data)) )
# Out:
# Percentage of 'other' Type of Answers in Dataset is  55.98290598290598
# Percentage of 'yes/no' Type of Answers in Dataset is  35.47008547008547
# Percentage of 'number' Type of Answers in Dataset is  8.547008547008547

# %%
sns.countplot(data["multiple_choice_answer"].apply(lambda x: len(x.split())).values)
plt.title("Number of words in Answers vs Distrubution")
plt.xlabel("Number of words in Answers")
plt.ylabel("Distrubution")
plt.show()

# %% [markdown]
# **QUESTION**

# %%
sns.countplot(data["question"].apply(lambda x: len(x.split())).values)
plt.title("Length of the questions vs Distrubution")
plt.xlabel("Length of the questions")
plt.ylabel("Distrubution")
plt.show()

# %% [markdown]
# **QUESTION TYPE AND ANSWER**

# %%
temp = data
top_question = [x[0] for x in question_type_frequncy[:50]]
print(top_question)
top_aswers = [x[0] for x in answer_type_frequncy[:50]]
print(top_aswers)
temp = data[(data['question_type'].isin(top_question) | data['multiple_choice_answer'].isin(top_aswers))]

aggregations = {'question': 'count'}
temp = pd.DataFrame(temp.groupby(['question_type','multiple_choice_answer'],as_index= False).agg(aggregations))
temp = temp[temp['question']>=10]
temp = temp.pivot(index='question_type', columns='multiple_choice_answer', values='question')
#print(temp)
# Out:
# ['what', 'is the', 'what color is the', 'how many', 'what is the', 'what kind of', 'what is', 'is there a', 'none of the above', 'is this', 'what type of', 'is this a', 'what are', 'what color are the', 'are the', 'where is the', 'what sport is', 'is it', 'what are the', 'how', 'are there', 'is the person', 'what is the man', 'is he', 'how many people are', 'are', 'is this an', 'why', 'what is the name', 'does the', 'are these', 'is this person', 'is there', 'what is on the', 'what is in the', 'is that a', 'is', 'is the man', 'who is', 'what number is', 'what room is', 'are they', 'what is the woman', 'where are the', 'what color', 'could', 'was', 'can you', 'do you', 'what time']
# ['other', 'yes/no', 'number']

# %% [markdown]
# **QUESTION TYPE VS ANSWER**

# %%
fig = plt.figure(figsize=(80,30))
fig.tight_layout() 
count = 1
colorCodes = [ "#E18719", "#287819", "#2D6EAA", "#E6AF23", "#666666","#724D8D", "#EAAB5E", "#73A769","#93785F",
              "#C97B7B", "#81A8CC", "#EDC765", "#858585","#957AA9", "#F3CFA3","#B4D0AF", "#BEADA0", "#E4BDBD", 
              "#ABC5DD", "#F4DB9C", "#A3A3A3"]

for _type,_ in question_type_frequncy[:12]:

    percentage = str(round((len(data[data['question_type']==_type])/len(data))*100,1))+'%'

    plt.subplot(4, 3, count)
    temp = data[data['question_type']==_type]
    ax = temp['multiple_choice_answer'].value_counts()[:10][::-1].plot(kind='barh', figsize=(20,15),color=colorCodes[count-1], fontsize=13)
    ax.set_alpha(0.8)   
    ax.set_title("Question Type:  '" + _type + "' (" + percentage + ") vs Answer" , fontsize=18)
    ax.set_ylabel("Answers", fontsize=18)
    ax.get_xaxis().set_visible(False)


    for i in ax.patches:
        ax.text(i.get_width()/2, i.get_y(), str(round((i.get_width()/len(temp))*100, 2))+'%' + "(" +
                str(round((i.get_width()/len(data))*100, 2))+'%' +")", fontsize=10,color='black')
        
    count += 1

fig.tight_layout()
plt.show()

# %% [markdown]
# **ANSWERS VS QUESTION TYPE**

# %%
fig = plt.figure()
fig.tight_layout() 
count = 1

colorCodes = [ "#E18719", "#287819", "#2D6EAA", "#E6AF23", "#666666","#724D8D", "#EAAB5E", "#73A769","#93785F",
              "#C97B7B", "#81A8CC", "#EDC765", "#858585","#957AA9", "#F3CFA3","#B4D0AF", "#BEADA0", "#E4BDBD", 
              "#ABC5DD", "#F4DB9C", "#A3A3A3"]

answer_frequncy = sorted(list(getFrequnctDict(data,'multiple_choice_answer').items()),key = lambda x: x[1],reverse=True)

for _type,_ in answer_frequncy[:12]:

    percentage = str(round((len(data[data['multiple_choice_answer']==_type])/len(data))*100,1))+'%'

    plt.subplot(4, 3, count)
    temp = data[data['multiple_choice_answer']==_type]
    ax = temp['question_type'].value_counts()[:10][::-1].plot(kind='barh', figsize=(20,15),color=colorCodes[count-1], fontsize=13)
    ax.set_alpha(0.8)   
    ax.set_title("Answer: '" + _type + "' (" + percentage + ") vs Question Type" , fontsize=18)
    ax.set_ylabel("Question Type", fontsize=18)
    ax.get_xaxis().set_visible(False)

    for i in ax.patches:
        ax.text(i.get_width()/2, i.get_y(), str(round((i.get_width()/len(temp))*100, 2))+'%' + "(" +
                str(round((i.get_width()/len(data))*100, 2))+'%' +")", fontsize=14,color='black')
        
    count += 1

fig.tight_layout()
plt.show()

# %% [markdown]
# **CHECKING IF ACTUAL ANSWER IS SAME AS PERSONS ANSWERS**

# %%
def getPeopleAnswer(answers):
    answers_dict = {}
    score_dict = { 'yes' : 3, 'maybe' : 2, 'no' : 1 }
    for _answer in answers:
        score = score_dict[_answer['answer_confidence']]
        if answers_dict.get(_answer['answer'],-1) != -1 :
            answers_dict[_answer['answer']] += score
        else:
            answers_dict[_answer['answer']] = score

    return sorted(list(answers_dict.items()),key = lambda x: x[1],reverse=True)[0][0]

# %%
#data['derived_answer'] =  data["answers"].apply(lambda x: getPeopleAnswer(x))

# %%
#data[ data['derived_answer'] != data['multiple_choice_answer']]

# %%
# !pwd
# Out:
# /content/train2014

# %%
dataDDirectory ='/content/drive/MyDrive/newresults'
os.chdir(dataDDirectory)
# !pwd
data.to_csv(dataDDirectory + 'data.csv')
# Out:
# /content/drive/MyDrive/newresults

# %%
os.listdir(dataDDirectory)
# Out:
# ['data',
#  '.ipynb_checkpoints',
#  'Models',
#  'filenamert.pickle',
#  'validation.hdf5',
#  'myhdfff5.hdf5',
#  'training.hdf5',
#  'my_vqas_model',
#  'VQAs_MODEL_WEIGHTS.hdf5']

# %% [markdown]
# **Modelling**

# %%
import warnings
warnings.filterwarnings("ignore")

import pickle
import os
import pandas as pd
import random as rn
import numpy as np
import tensorflow as tf
from google.colab import drive
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.regularizers import l1,l2
from tqdm import tqdm
import heapq
from sklearn.utils import shuffle
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from sklearn.model_selection import train_test_split
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Variables**

# %%
currentDirectory = "/content/drive/MyDrive/newresults/"
os.chdir(currentDirectory)
currentDirectory = ""
dataDirectory = currentDirectory + "data/"
#imageDirectory = dataDirectory + "train2014/"
imageDirectory = '/content/train2014/'
imageNumpyDirectory = dataDirectory + "train2014_Numpy" + ''

modelsDirectory = currentDirectory + "Models/"


img_width = 224
img_height = 224

BATCH_SIZE = 64
#BATCH_SIZE = 1
BUFFER_SIZE = 300

# %%
#len(os.listdir(imageNumpyDirectory))
data = pd.read_csv(dataDDirectory + 'data.csv')
X_train, X_val = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# **Creating answer vectors**

# %%
contractions = { 
"ain't": "am not","aren't": "are not","can't": "cannot","can't've": "cannot have","'cause": "because","could've": "could have","couldn't": "could not",
"couldn't've": "could not have","didn't": "did not","doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have",
"hasn't": "has not","haven't": "have not","he'd": "he would","he'd've": "he would have","he'll": "he will","he's": "he is","how'd": "how did",
"how'll": "how will","how's": "how is","i'd": "i would","i'll": "i will","i'm": "i am","i've": "i have","isn't": "is not","it'd": "it would",
"it'll": "it will","it's": "it is","let's": "let us","ma'am": "madam","mayn't": "may not","might've": "might have","mightn't": "might not",
"must've": "must have","mustn't": "must not","needn't": "need not","oughtn't": "ought not","shan't": "shall not","sha'n't": "shall not","she'd": "she would",
"she'll": "she will","she's": "she is","should've": "should have","shouldn't": "should not","that'd": "that would","that's": "that is","there'd": "there had",
"there's": "there is","they'd": "they would","they'll": "they will","they're": "they are","they've": "they have","wasn't": "was not","we'd": "we would",
"we'll": "we will","we're": "we are","we've": "we have","weren't": "were not","what'll": "what will","what're": "what are","what's": "what is",
"what've": "what have","where'd": "where did","where's": "where is","who'll": "who will","who's": "who is","won't": "will not","wouldn't": "would not",
"you'd": "you would","you'll": "you will","you're": "you are"
}

def preprocess_english(text):
    '''Given a text this function removes the punctuations and returns the remaining text string'''
    new_text = ""
    text = text.lower()
    i = 0
    for word in text.split():
      if i==0:
        new_text = contractions.get(word,word)
      else:
        new_text = new_text + " " + contractions.get(word,word)
      i += 1
    return new_text.replace("'s", '')

# %%
X_train['multiple_choice_answer'] = X_train['multiple_choice_answer'].apply(lambda x: preprocess_english(x))
X_val['multiple_choice_answer'] = X_val['multiple_choice_answer'].apply(lambda x: preprocess_english(x))

# %%
all_classes = X_train['multiple_choice_answer'].values
class_frequency = {}

for _cls in all_classes:
    if(class_frequency.get(_cls,-1)>0):
        class_frequency[_cls] += 1
    else:
        class_frequency[_cls] = 1

# %%
sort_class_frequency = sorted(list(class_frequency.items()),key = lambda x: x[1],reverse=True)   

plt.plot([x[1] for x in sort_class_frequency[:30]])
i=np.arange(30)
plt.title("Frequency of top 30 Classes")
plt.xlabel("Tags")
plt.ylabel("Counts")
plt.xticks(i,[x[0] for x in sort_class_frequency[:30]])
plt.xticks(rotation=90)
plt.show()

# %%
def getPercentageOfDataCoversGivenNumClasses(n_class, class_frequency, df):
    n_common_class = heapq.nlargest(n_class, class_frequency, key=class_frequency.get)
    count = 0
    for _class in df['multiple_choice_answer'].values:
        if(_class in n_common_class):
            count += 1

    return (count/len(df))*100
    
n_classes = [5,10,20,50,70,100,200,500,750,1000,2000,3000,5000]
percentage_cover = []
for i in n_classes:
    temp = getPercentageOfDataCoversGivenNumClasses(i,class_frequency,X_train)
    percentage_cover.append(temp)
    print("{} most frequent Classes covers {:.2f}% points".format(i,temp))


plt.plot(percentage_cover)
i=np.arange(len(percentage_cover))
plt.title("Percentage of points covers vs number of Classes")
plt.xlabel("Classes")
plt.ylabel("Counts")
plt.xticks(i,n_classes)
plt.show()
# Out:
# 5 most frequent Classes covers 43.85% points
# 10 most frequent Classes covers 49.20% points
# 20 most frequent Classes covers 56.15% points
# 50 most frequent Classes covers 72.19% points
# 70 most frequent Classes covers 82.89% points
# 100 most frequent Classes covers 98.93% points
# 200 most frequent Classes covers 100.00% points
# 500 most frequent Classes covers 100.00% points
# 750 most frequent Classes covers 100.00% points
# 1000 most frequent Classes covers 100.00% points
# 2000 most frequent Classes covers 100.00% points
# 3000 most frequent Classes covers 100.00% points
# 5000 most frequent Classes covers 100.00% points

# %%
common_tags = heapq.nlargest(1000, class_frequency, key = class_frequency.get)
X_train['multiple_choice_answer'] =  X_train['multiple_choice_answer'].apply(lambda x: x if x in common_tags else '')

#removing question which has empty tags
X_train = X_train[X_train['multiple_choice_answer'].apply(lambda x: len(x)>0)]

# %%
label_encoder = LabelBinarizer()
answer_vector_train = label_encoder.fit_transform(X_train['multiple_choice_answer'].apply(lambda x: x).values)
answer_vector_val = label_encoder.transform(X_val['multiple_choice_answer'].apply(lambda x: x).values)

ans_vocab = {l: i for i, l in enumerate(label_encoder.classes_)}

print("Number of clasess: ", len(ans_vocab))
print("Shape of Answer Vectors in Train Data: ", answer_vector_train.shape)
print("Shape of Answer Vectors in Validation Data: ", answer_vector_val.shape)
# Out:
# Number of clasess:  102
# Shape of Answer Vectors in Train Data:  (187, 102)
# Shape of Answer Vectors in Validation Data:  (47, 102)

# %% [markdown]
# **Creating Image features using VGG19**

# %%
import pickle
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU
import tensorflow as tf
from tensorflow import keras
import keras.layers as layers
import math
from tensorflow import keras
#from tensorflow.keras import layers

def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    print("img after channels shape")
    print(img.shape)
    img = tf.image.resize(img, (img_width, img_height))
    print("img after resize shape")
    print(img.shape)
    
    #img = tf.keras.applications.vgg19.preprocess_input(img)
    img = img * (1./255)
    return img, image_path


def Alex_Top():
  print("Toy ResNet model for CIFAR10")
  print("Layers generated for model")
  inputs = keras.Input(shape=(224, 224, 3), name="img")
  x = layers.Conv2D(32, 3, activation="relu")(inputs)
  x = layers.Conv2D(64, 3, activation="relu")(x)
  block_1_output = layers.MaxPooling2D(3)(x)

  x = layers.Conv2D(64, 3, activation="relu", padding="same")(block_1_output)
  x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
  block_2_output = layers.add([x, block_1_output])

  x = layers.Conv2D(64, 3, activation="relu", padding="same")(block_2_output)
  x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
  block_3_output = layers.add([x, block_2_output])

  x = layers.Conv2D(64, 3, activation="relu")(block_3_output)
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(256, activation="relu")(x)
  x = layers.Dropout(0.5)(x)
  outputs = layers.Dense(10)(x)

  model = keras.Model(inputs, outputs, name="toy_resnet")
  print("More information about the model")
  model.summary()
  return model
  
    


    

def generateImageFeatures(images):
    model = Alex_Top()
    all_image_dict = {}
  
    img_ds = tf.data.Dataset.from_tensor_slices(images)
    img_ds = img_ds.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)
    
    for batch_img, batch_path in img_ds:
        batch_img_features = model(batch_img)
        #print(batch_img_features)

        for img_features, path in zip(batch_img_features, batch_path):
            image_path = path.numpy().decode("utf-8")
            print(image_path)
            
            
            image_path = image_path.replace(imageDirectory,'/content/drive/MyDrive/newresults/data'+'/'+'train2014_Numpy').replace('.jpg',"")
            print(image_path)
            np.save(image_path, img_features.numpy())
            all_image_dict[image_path] = img_features.numpy()
            print("Printing image features")
            #print(all_image_dict[image_path])
    
    with open('filenamert.pickle', 'wb') as handle:
        pickle.dump(all_image_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    return

# !pwd
all_image_path = data['image_id'].apply(lambda x:  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (x)).unique()

  


generateImageFeatures(all_image_path)
# Out:
# /content/drive/MyDrive/newresults
# Toy ResNet model for CIFAR10
# Layers generated for model
# More information about the model
# Model: "toy_resnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_14 (Conv2D)             (None, 222, 222, 32  896         ['img[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 220, 220, 64  18496       ['conv2d_14[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 73, 73, 64)  0           ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 73, 73, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 73, 73, 64)   36928       ['conv2d_16[0][0]']
#
#  add_4 (Add)                    (None, 73, 73, 64)   0           ['conv2d_17[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 73, 73, 64)   36928       ['add_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 73, 73, 64)   36928       ['conv2d_18[0][0]']
#
#  add_5 (Add)                    (None, 73, 73, 64)   0           ['conv2d_19[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 71, 71, 64)   36928       ['add_5[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 64)          0           ['conv2d_20[0][0]']
#  obalAveragePooling2D)
#
#  dense_14 (Dense)               (None, 256)          16640       ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dropout_2 (Dropout)            (None, 256)          0           ['dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 10)           2570        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 223,242
# Trainable params: 223,242
# Non-trainable params: 0
# __________________________________________________________________________________________________
# img after channels shape
# (None, None, 3)
# img after resize shape
# (224, 224, 3)
# /content/train2014/COCO_train2014_000000269126.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000269126
# Printing image features
# /content/train2014/COCO_train2014_000000075521.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000075521
# Printing image features
# /content/train2014/COCO_train2014_000000367125.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000367125
# Printing image features
# /content/train2014/COCO_train2014_000000149812.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000149812
# Printing image features
# /content/train2014/COCO_train2014_000000103447.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000103447
# Printing image features
# /content/train2014/COCO_train2014_000000395050.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000395050
# Printing image features
# /content/train2014/COCO_train2014_000000319104.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000319104
# Printing image features
# /content/train2014/COCO_train2014_000000498615.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000498615
# Printing image features
# /content/train2014/COCO_train2014_000000435553.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000435553
# Printing image features
# /content/train2014/COCO_train2014_000000109145.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000109145
# Printing image features
# /content/train2014/COCO_train2014_000000082901.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000082901
# Printing image features
# /content/train2014/COCO_train2014_000000048670.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000048670
# Printing image features
# /content/train2014/COCO_train2014_000000371940.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000371940
# Printing image features
# /content/train2014/COCO_train2014_000000385709.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000385709
# Printing image features
# /content/train2014/COCO_train2014_000000210686.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000210686
# Printing image features
# /content/train2014/COCO_train2014_000000054162.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000054162
# Printing image features
# /content/train2014/COCO_train2014_000000354326.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000354326
# Printing image features
# /content/train2014/COCO_train2014_000000326610.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000326610
# Printing image features
# /content/train2014/COCO_train2014_000000560202.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000560202
# Printing image features
# /content/train2014/COCO_train2014_000000322027.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000322027
# Printing image features
# /content/train2014/COCO_train2014_000000105933.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000105933
# Printing image features
# /content/train2014/COCO_train2014_000000185547.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000185547
# Printing image features
# /content/train2014/COCO_train2014_000000223636.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000223636
# Printing image features
# /content/train2014/COCO_train2014_000000148502.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000148502
# Printing image features
# /content/train2014/COCO_train2014_000000151307.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000151307
# Printing image features
# /content/train2014/COCO_train2014_000000485894.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000485894
# Printing image features
# /content/train2014/COCO_train2014_000000282006.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000282006
# Printing image features
# /content/train2014/COCO_train2014_000000329354.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000329354
# Printing image features
# /content/train2014/COCO_train2014_000000410779.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000410779
# Printing image features
# /content/train2014/COCO_train2014_000000527748.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000527748
# Printing image features
# /content/train2014/COCO_train2014_000000297141.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000297141
# Printing image features
# /content/train2014/COCO_train2014_000000190537.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000190537
# Printing image features
# /content/train2014/COCO_train2014_000000119129.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000119129
# Printing image features
# /content/train2014/COCO_train2014_000000290072.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000290072
# Printing image features
# /content/train2014/COCO_train2014_000000545804.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000545804
# Printing image features
# /content/train2014/COCO_train2014_000000451213.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000451213
# Printing image features
# /content/train2014/COCO_train2014_000000494574.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000494574
# Printing image features
# /content/train2014/COCO_train2014_000000334381.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000334381
# Printing image features
# /content/train2014/COCO_train2014_000000484362.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000484362
# Printing image features
# /content/train2014/COCO_train2014_000000419410.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000419410
# Printing image features
# /content/train2014/COCO_train2014_000000444210.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000444210
# Printing image features
# /content/train2014/COCO_train2014_000000228172.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000228172
# Printing image features
# /content/train2014/COCO_train2014_000000558836.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000558836
# Printing image features
# /content/train2014/COCO_train2014_000000208413.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000208413
# Printing image features
# /content/train2014/COCO_train2014_000000014872.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000014872
# Printing image features
# /content/train2014/COCO_train2014_000000347865.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000347865
# Printing image features
# /content/train2014/COCO_train2014_000000437542.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000437542
# Printing image features
# /content/train2014/COCO_train2014_000000182242.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000182242
# Printing image features
# /content/train2014/COCO_train2014_000000285821.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000285821
# Printing image features
# /content/train2014/COCO_train2014_000000096365.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000096365
# Printing image features
# /content/train2014/COCO_train2014_000000298418.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000298418
# Printing image features
# /content/train2014/COCO_train2014_000000351972.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000351972
# Printing image features
# /content/train2014/COCO_train2014_000000140349.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000140349
# Printing image features
# /content/train2014/COCO_train2014_000000415551.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000415551
# Printing image features
# /content/train2014/COCO_train2014_000000307371.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000307371
# Printing image features
# /content/train2014/COCO_train2014_000000403955.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000403955
# Printing image features
# /content/train2014/COCO_train2014_000000560359.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000560359
# Printing image features
# /content/train2014/COCO_train2014_000000356369.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000356369
# Printing image features
# /content/train2014/COCO_train2014_000000136668.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000136668
# Printing image features
# /content/train2014/COCO_train2014_000000454864.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000454864
# Printing image features
# /content/train2014/COCO_train2014_000000490507.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000490507
# Printing image features
# /content/train2014/COCO_train2014_000000173451.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000173451
# Printing image features
# /content/train2014/COCO_train2014_000000003293.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000003293
# Printing image features
# /content/train2014/COCO_train2014_000000490411.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000490411
# Printing image features
# /content/train2014/COCO_train2014_000000484714.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000484714
# Printing image features
# /content/train2014/COCO_train2014_000000100439.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000100439
# Printing image features
# /content/train2014/COCO_train2014_000000009658.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000009658
# Printing image features
# /content/train2014/COCO_train2014_000000198786.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000198786
# Printing image features
# /content/train2014/COCO_train2014_000000012098.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000012098
# Printing image features
# /content/train2014/COCO_train2014_000000299623.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000299623
# Printing image features
# /content/train2014/COCO_train2014_000000254902.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000254902
# Printing image features
# /content/train2014/COCO_train2014_000000564684.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000564684
# Printing image features
# /content/train2014/COCO_train2014_000000057250.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000057250
# Printing image features
# /content/train2014/COCO_train2014_000000579045.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000579045
# Printing image features
# /content/train2014/COCO_train2014_000000360831.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000360831
# Printing image features
# /content/train2014/COCO_train2014_000000224134.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000224134
# Printing image features
# /content/train2014/COCO_train2014_000000186280.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000186280
# Printing image features
# /content/train2014/COCO_train2014_000000319626.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000319626
# Printing image features
# /content/train2014/COCO_train2014_000000337779.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000337779
# Printing image features
# /content/train2014/COCO_train2014_000000472089.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000472089
# Printing image features
# /content/train2014/COCO_train2014_000000160214.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000160214
# Printing image features
# /content/train2014/COCO_train2014_000000502493.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000502493
# Printing image features
# /content/train2014/COCO_train2014_000000515210.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000515210
# Printing image features
# /content/train2014/COCO_train2014_000000565401.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000565401
# Printing image features
# /content/train2014/COCO_train2014_000000018584.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000018584
# Printing image features
# /content/train2014/COCO_train2014_000000172264.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000172264
# Printing image features
# /content/train2014/COCO_train2014_000000420210.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000420210
# Printing image features
# /content/train2014/COCO_train2014_000000532635.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000532635
# Printing image features
# /content/train2014/COCO_train2014_000000569742.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000569742
# Printing image features
# /content/train2014/COCO_train2014_000000494211.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000494211
# Printing image features
# /content/train2014/COCO_train2014_000000288194.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000288194
# Printing image features
# /content/train2014/COCO_train2014_000000217306.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000217306
# Printing image features
# /content/train2014/COCO_train2014_000000290024.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000290024
# Printing image features
# /content/train2014/COCO_train2014_000000015518.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000015518
# Printing image features
# /content/train2014/COCO_train2014_000000504554.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000504554
# Printing image features
# /content/train2014/COCO_train2014_000000163176.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000163176
# Printing image features
# /content/train2014/COCO_train2014_000000310660.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000310660
# Printing image features
# /content/train2014/COCO_train2014_000000087685.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000087685
# Printing image features
# /content/train2014/COCO_train2014_000000027307.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000027307
# Printing image features
# /content/train2014/COCO_train2014_000000494676.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000494676
# Printing image features
# /content/train2014/COCO_train2014_000000165077.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000165077
# Printing image features
# /content/train2014/COCO_train2014_000000116397.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000116397
# Printing image features
# /content/train2014/COCO_train2014_000000080950.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000080950
# Printing image features
# /content/train2014/COCO_train2014_000000070307.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000070307
# Printing image features
# /content/train2014/COCO_train2014_000000202855.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000202855
# Printing image features
# /content/train2014/COCO_train2014_000000037122.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000037122
# Printing image features
# /content/train2014/COCO_train2014_000000330807.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000330807
# Printing image features
# /content/train2014/COCO_train2014_000000120737.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000120737
# Printing image features
# /content/train2014/COCO_train2014_000000538250.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000538250
# Printing image features
# /content/train2014/COCO_train2014_000000205486.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000205486
# Printing image features
# /content/train2014/COCO_train2014_000000012138.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000012138
# Printing image features
# /content/train2014/COCO_train2014_000000117884.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000117884
# Printing image features
# /content/train2014/COCO_train2014_000000313605.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000313605
# Printing image features
# /content/train2014/COCO_train2014_000000426073.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000426073
# Printing image features
# /content/train2014/COCO_train2014_000000494768.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000494768
# Printing image features
# /content/train2014/COCO_train2014_000000311290.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000311290
# Printing image features
# /content/train2014/COCO_train2014_000000462791.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000462791
# Printing image features
# /content/train2014/COCO_train2014_000000073790.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000073790
# Printing image features
# /content/train2014/COCO_train2014_000000115145.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000115145
# Printing image features
# /content/train2014/COCO_train2014_000000370252.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000370252
# Printing image features
# /content/train2014/COCO_train2014_000000219225.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000219225
# Printing image features
# /content/train2014/COCO_train2014_000000398799.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000398799
# Printing image features
# /content/train2014/COCO_train2014_000000181054.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000181054
# Printing image features
# /content/train2014/COCO_train2014_000000186753.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000186753
# Printing image features
# /content/train2014/COCO_train2014_000000249058.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000249058
# Printing image features
# /content/train2014/COCO_train2014_000000078542.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000078542
# Printing image features
# /content/train2014/COCO_train2014_000000500576.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000500576
# Printing image features
# /content/train2014/COCO_train2014_000000364535.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000364535
# Printing image features
# /content/train2014/COCO_train2014_000000167369.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000167369
# Printing image features
# /content/train2014/COCO_train2014_000000535860.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000535860
# Printing image features
# /content/train2014/COCO_train2014_000000177050.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000177050
# Printing image features
# /content/train2014/COCO_train2014_000000547869.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000547869
# Printing image features
# /content/train2014/COCO_train2014_000000247368.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000247368
# Printing image features
# /content/train2014/COCO_train2014_000000025885.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000025885
# Printing image features
# /content/train2014/COCO_train2014_000000534266.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000534266
# Printing image features
# /content/train2014/COCO_train2014_000000048929.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000048929
# Printing image features
# /content/train2014/COCO_train2014_000000012766.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000012766
# Printing image features
# /content/train2014/COCO_train2014_000000488014.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000488014
# Printing image features
# /content/train2014/COCO_train2014_000000175655.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000175655
# Printing image features
# /content/train2014/COCO_train2014_000000293353.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000293353
# Printing image features
# /content/train2014/COCO_train2014_000000379487.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000379487
# Printing image features
# /content/train2014/COCO_train2014_000000550099.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000550099
# Printing image features
# /content/train2014/COCO_train2014_000000402847.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000402847
# Printing image features
# /content/train2014/COCO_train2014_000000286439.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000286439
# Printing image features
# /content/train2014/COCO_train2014_000000523055.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000523055
# Printing image features
# /content/train2014/COCO_train2014_000000080634.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000080634
# Printing image features
# /content/train2014/COCO_train2014_000000533154.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000533154
# Printing image features
# /content/train2014/COCO_train2014_000000324406.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000324406
# Printing image features
# /content/train2014/COCO_train2014_000000406756.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000406756
# Printing image features
# /content/train2014/COCO_train2014_000000059024.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000059024
# Printing image features
# /content/train2014/COCO_train2014_000000413391.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000413391
# Printing image features
# /content/train2014/COCO_train2014_000000064149.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000064149
# Printing image features
# /content/train2014/COCO_train2014_000000543027.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000543027
# Printing image features
# /content/train2014/COCO_train2014_000000479550.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000479550
# Printing image features
# /content/train2014/COCO_train2014_000000565641.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000565641
# Printing image features
# /content/train2014/COCO_train2014_000000119276.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000119276
# Printing image features
# /content/train2014/COCO_train2014_000000553918.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000553918
# Printing image features
# /content/train2014/COCO_train2014_000000021169.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000021169
# Printing image features
# /content/train2014/COCO_train2014_000000569520.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000569520
# Printing image features
# /content/train2014/COCO_train2014_000000102090.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000102090
# Printing image features
# /content/train2014/COCO_train2014_000000522350.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000522350
# Printing image features
# /content/train2014/COCO_train2014_000000148306.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000148306
# Printing image features
# /content/train2014/COCO_train2014_000000034459.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000034459
# Printing image features
# /content/train2014/COCO_train2014_000000442220.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000442220
# Printing image features
# /content/train2014/COCO_train2014_000000144345.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000144345
# Printing image features
# /content/train2014/COCO_train2014_000000487962.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000487962
# Printing image features
# /content/train2014/COCO_train2014_000000542991.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000542991
# Printing image features
# /content/train2014/COCO_train2014_000000019037.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000019037
# Printing image features
# /content/train2014/COCO_train2014_000000290864.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000290864
# Printing image features
# /content/train2014/COCO_train2014_000000259248.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000259248
# Printing image features
# /content/train2014/COCO_train2014_000000033297.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000033297
# Printing image features
# /content/train2014/COCO_train2014_000000325799.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000325799
# Printing image features
# /content/train2014/COCO_train2014_000000532866.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000532866
# Printing image features
# /content/train2014/COCO_train2014_000000248116.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000248116
# Printing image features
# /content/train2014/COCO_train2014_000000131534.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000131534
# Printing image features
# /content/train2014/COCO_train2014_000000205338.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000205338
# Printing image features
# /content/train2014/COCO_train2014_000000295020.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000295020
# Printing image features
# /content/train2014/COCO_train2014_000000263764.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000263764
# Printing image features
# /content/train2014/COCO_train2014_000000543922.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000543922
# Printing image features
# /content/train2014/COCO_train2014_000000013914.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000013914
# Printing image features
# /content/train2014/COCO_train2014_000000322827.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000322827
# Printing image features
# /content/train2014/COCO_train2014_000000207880.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000207880
# Printing image features
# /content/train2014/COCO_train2014_000000335758.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000335758
# Printing image features
# /content/train2014/COCO_train2014_000000337594.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000337594
# Printing image features
# /content/train2014/COCO_train2014_000000182968.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000182968
# Printing image features
# /content/train2014/COCO_train2014_000000194941.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000194941
# Printing image features
# /content/train2014/COCO_train2014_000000533258.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000533258
# Printing image features
# /content/train2014/COCO_train2014_000000379294.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000379294
# Printing image features
# /content/train2014/COCO_train2014_000000486513.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000486513
# Printing image features
# /content/train2014/COCO_train2014_000000065668.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000065668
# Printing image features
# /content/train2014/COCO_train2014_000000141827.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000141827
# Printing image features
# /content/train2014/COCO_train2014_000000160313.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000160313
# Printing image features
# /content/train2014/COCO_train2014_000000411773.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000411773
# Printing image features
# /content/train2014/COCO_train2014_000000017946.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000017946
# Printing image features
# /content/train2014/COCO_train2014_000000051574.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000051574
# Printing image features
# /content/train2014/COCO_train2014_000000101820.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000101820
# Printing image features
# /content/train2014/COCO_train2014_000000158432.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000158432
# Printing image features
# /content/train2014/COCO_train2014_000000299689.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000299689
# Printing image features
# /content/train2014/COCO_train2014_000000042621.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000042621
# Printing image features
# /content/train2014/COCO_train2014_000000526082.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000526082
# Printing image features
# /content/train2014/COCO_train2014_000000539671.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000539671
# Printing image features
# /content/train2014/COCO_train2014_000000541226.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000541226
# Printing image features
# /content/train2014/COCO_train2014_000000408829.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000408829
# Printing image features
# /content/train2014/COCO_train2014_000000084221.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000084221
# Printing image features
# /content/train2014/COCO_train2014_000000259629.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000259629
# Printing image features
# /content/train2014/COCO_train2014_000000454892.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000454892
# Printing image features
# /content/train2014/COCO_train2014_000000105633.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000105633
# Printing image features
# /content/train2014/COCO_train2014_000000398214.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000398214
# Printing image features
# /content/train2014/COCO_train2014_000000360637.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000360637
# Printing image features
# /content/train2014/COCO_train2014_000000417298.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000417298
# Printing image features
# /content/train2014/COCO_train2014_000000111348.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000111348
# Printing image features
# /content/train2014/COCO_train2014_000000394596.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000394596
# Printing image features
# /content/train2014/COCO_train2014_000000196104.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000196104
# Printing image features
# /content/train2014/COCO_train2014_000000504730.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000504730
# Printing image features
# /content/train2014/COCO_train2014_000000509876.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000509876
# Printing image features
# /content/train2014/COCO_train2014_000000537656.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000537656
# Printing image features
# /content/train2014/COCO_train2014_000000377488.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000377488
# Printing image features
# /content/train2014/COCO_train2014_000000291841.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000291841
# Printing image features
# /content/train2014/COCO_train2014_000000556695.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000556695
# Printing image features
# /content/train2014/COCO_train2014_000000099844.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000099844
# Printing image features
# /content/train2014/COCO_train2014_000000436774.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000436774
# Printing image features
# /content/train2014/COCO_train2014_000000288310.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000288310
# Printing image features
# /content/train2014/COCO_train2014_000000564481.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000564481
# Printing image features
# /content/train2014/COCO_train2014_000000121110.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000121110
# Printing image features
# /content/train2014/COCO_train2014_000000039764.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000039764
# Printing image features
# /content/train2014/COCO_train2014_000000302662.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000302662
# Printing image features
# /content/train2014/COCO_train2014_000000451107.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000451107
# Printing image features
# /content/train2014/COCO_train2014_000000393661.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000393661
# Printing image features
# /content/train2014/COCO_train2014_000000562804.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000562804
# Printing image features
# /content/train2014/COCO_train2014_000000019671.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000019671
# Printing image features
# /content/train2014/COCO_train2014_000000131190.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000131190
# Printing image features
# /content/train2014/COCO_train2014_000000517087.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000517087
# Printing image features
# /content/train2014/COCO_train2014_000000062778.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000062778
# Printing image features
# /content/train2014/COCO_train2014_000000119118.jpg
# /content/drive/MyDrive/newresults/data/train2014_NumpyCOCO_train2014_000000119118
# Printing image features

# %%
'''model = keras.Sequential()
    model.add(layers.Conv2D(filters=96, kernel_size=(11, 11), 
                        strides=(4, 4), activation="relu", 
                        input_shape=(227, 227, 3)))

    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(3, 3), strides= (2, 2)))
    model.add(layers.Conv2D(filters=256, kernel_size=(5, 5), 
                        strides=(1, 1), activation="relu", 
                        padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(layers.Conv2D(filters=384, kernel_size=(3, 3), 
                        strides=(1, 1), activation="relu", 
                        padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(filters=384, kernel_size=(3, 3), 
                        strides=(1, 1), activation="relu", 
                        padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), 
                        strides=(1, 1), activation="relu", 
                        padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(86, activation="relu"))
    model.add(layers.Dropout(0.5))
    
    return model'''
# Out:
# 'model = keras.Sequential()\n    model.add(layers.Conv2D(filters=96, kernel_size=(11, 11), \n                        strides=(4, 4), activation="relu", \n                        input_shape=(227, 227, 3)))\n\n    model.add(layers.BatchNormalization())\n    model.add(layers.MaxPool2D(pool_size=(3, 3), strides= (2, 2)))\n    model.add(layers.Conv2D(filters=256, kernel_size=(5, 5), \n                        strides=(1, 1), activation="relu", \n                        padding="same"))\n    model.add(layers.BatchNormalization())\n    model.add(layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2)))\n    model.add(layers.Conv2D(filters=384, kernel_size=(3, 3), \n                        strides=(1, 1), activation="relu", \n                        padding="same"))\n    model.add(layers.BatchNormalization())\n    model.add(layers.Conv2D(filters=384, kernel_size=(3, 3), \n                        strides=(1, 1), activation="relu", \n                        padding="same"))\n    model.add(layers.BatchNormalization())\n    model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), \n                        strides=(1, 1), activation="relu", \n                        padding="same"))\n    model.add(layers.BatchNormalization())\n    model.add(layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2)))\n    model.add(layers.Flatten())\n    model.add(layers.Dense(86, activation="relu"))\n    model.add(layers.Dropout(0.5))\n    \n    return model'

# %%
print(imageDirectory)
# Out:
# /content/train2014/

# %%
image_paths_train = X_train['image_id'].apply(lambda x:  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (x)).values
image_paths_val = X_val['image_id'].apply(lambda x:  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (x)).values
#print(image_paths_train)
with open('filenamert.pickle','rb') as handle:
    all_image_dict = pickle.load(handle)

#with open('all_image_dict_new.pickle', 'rb') as handle:
    #all_image_dict_new = pickle.load(handle)

all_image_dict.update(all_image_dict)
#del all_image_dict_new

# %%
print(type(image_paths_train))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# **Creating question vectors**

# %%
def preprocess_english(text):
    '''Given a text this function removes the punctuations and returns the remaining text string'''
    new_text = "<start>"
    text = text.lower()
    for word in text.split():
      new_text = new_text + " " + contractions.get(word,word)
    new_text = new_text + " <end>"
    return new_text.replace("'s", '')

# %%
X_train['question'] = X_train['question'].apply(lambda x: preprocess_english(x))
X_val['question'] = X_val['question'].apply(lambda x: preprocess_english(x))

# %%
#tokenization
tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token = "<unk>", filters = '!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(X_train['question'].values)
train_question_seqs = tokenizer.texts_to_sequences(X_train['question'].values)
val_question_seqs = tokenizer.texts_to_sequences(X_val['question'].values)

print("Number of words in tokenizer:", len(tokenizer.word_index))
ques_vocab = tokenizer.word_index

#Padding
#tokenizer.word_index['<pad>'] = 0
#tokenizer.index_word[0] = '<pad>'
question_vector_train = tf.keras.preprocessing.sequence.pad_sequences(train_question_seqs, padding='post')
question_vector_val = tf.keras.preprocessing.sequence.pad_sequences(val_question_seqs,padding='post',maxlen=question_vector_train.shape[1])

print("Shape of Question Vectors in Train Data: ", question_vector_train.shape)
print("Shape of Question Vectors in Validation Data: ", question_vector_val.shape)
# Out:
# Number of words in tokenizer: 355
# Shape of Question Vectors in Train Data:  (187, 17)
# Shape of Question Vectors in Validation Data:  (47, 17)

# %% [markdown]
# **Creating dataset**

# %%
def get_imageTensor(img, ques):
    path = img.decode('utf-8').replace(imageDirectory,'/content/drive/MyDrive/newresults/data'+'/'+'train2014_Numpy').replace('.jpg',"") +'.npy'
    
    img_tensor = np.load(path)
    #img_tensor = all_image_dict[img.decode('utf-8')]
    
    return img_tensor, ques

# %%
def createDataset(image_paths,question_vector,answer_vector):
    dataset_input = tf.data.Dataset.from_tensor_slices((image_paths, question_vector.astype(np.float32)))
    dataset_output = tf.data.Dataset.from_tensor_slices((answer_vector.astype(np.float32)))
    # using map to load the numpy files in parallel
    dataset_input = dataset_input.map(lambda img, ques : tf.numpy_function(get_imageTensor, [img, ques], [tf.float32, tf.float32]),
                                      num_parallel_calls=tf.data.experimental.AUTOTUNE)

    # shuffling and batching
    #dataset_input = dataset_input.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
    dataset_input = dataset_input.batch(BATCH_SIZE)
    
    dataset_output = dataset_output.batch(BATCH_SIZE)#.repeat()
    
    dataset = tf.data.Dataset.zip((dataset_input, dataset_output))
    dataset = dataset.prefetch(buffer_size = tf.data.experimental.AUTOTUNE)

    return dataset

# %%
dataset_train = createDataset(image_paths_train, question_vector_train, answer_vector_train)
dataset_val = createDataset(image_paths_val, question_vector_val, answer_vector_val)
print(dataset_train)
# Out:
# <PrefetchDataset element_spec=((TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None)), TensorSpec(shape=(None, 102), dtype=tf.float32, name=None))>

# %%
print(type(dataset_train))
print(dataset_train)
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>
# <PrefetchDataset element_spec=((TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None)), TensorSpec(shape=(None, 102), dtype=tf.float32, name=None))>

# %%
hdf5_dict = {
    
    "train_images": image_paths_train,
    "train_ques": question_vector_train.astype(np.float32),
    "train_ans": answer_vector_train.astype(np.float32)
}

# %%
print(type(dataset_train))
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
import h5py

# %%
# !pwd
# Out:
# /content/drive/MyDrive/newresults

# %%
# create HDF5 file
with h5py.File('myhdfff5.hdf5', 'w') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    dt = h5py.special_dtype(vlen = np.dtype('float64'))
    dset_x_imgtrain = hf.create_dataset('imgg_train', data=image_paths_train)
    print(dset_x_imgtrain)
    dset_x_questrain = hf.create_dataset('quess_train', data=question_vector_train)
    dset_x_anstrain = hf.create_dataset('anss_train', data=answer_vector_train)
    '''for each in dset_x_anstrain:
      print(each)'''
# Out:
# list of dataset in this file:
#  []
# <HDF5 dataset "imgg_train": shape (187,), type "|O">

# %%
# create HDF5 file
with h5py.File('training.hdf5', 'w') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    dt = h5py.special_dtype(vlen = np.dtype('float64'))
    dset_x_imgtrain = hf.create_dataset('imgg_train', data=image_paths_train)
    print(dset_x_imgtrain)
    dset_x_questrain = hf.create_dataset('quess_train', data=question_vector_train)
    dset_x_anstrain = hf.create_dataset('anss_train', data=answer_vector_train)
# Out:
# list of dataset in this file:
#  []
# <HDF5 dataset "imgg_train": shape (187,), type "|O">

# %%
# create HDF5 file
with h5py.File('training.hdf5', 'r') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    img_data = hf.get('imgg_train')
    img_data1 = np.array(img_data)
    print(img_data1.shape)
    ques_data = hf.get('quess_train')
    ques_data1 = np.array(ques_data)
    print(ques_data1.shape)
    anss_data = hf.get('anss_train')
    anss_data1 = np.array(anss_data)
    print(anss_data1.shape)
# Out:
# list of dataset in this file:
#  ['anss_train', 'imgg_train', 'quess_train']
# (187,)
# (187, 17)
# (187, 102)

# %%
# create HDF5 file
with h5py.File('validation.hdf5', 'w') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    dt = h5py.special_dtype(vlen = np.dtype('float64'))
    dset_x_imgval = hf.create_dataset('imgg_val', data=image_paths_val)
    print(dset_x_imgtrain)
    dset_x_quesval = hf.create_dataset('quess_val', data=question_vector_val)
    dset_x_ansval = hf.create_dataset('anss_val', data=answer_vector_val)
# Out:
# list of dataset in this file:
#  []
# <Closed HDF5 dataset>

# %%
print(dset_x_anstrain)
# Out:
# <Closed HDF5 dataset>

# %% [markdown]
# **Baseline Model**

# %%
##fixing numpy RS
np.random.seed(42)

##fixing tensorflow RS
tf.random.set_seed(32)

##python RS
rn.seed(12)

# %%
'''def callBacksList():
    """
    returns list of callback's
    """
    filepath = modelsDirectory + ModelName + "/best.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = filepath, monitor = 'val_accuracy', verbose = 1, save_best_only = True, mode = 'auto')
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', patience = 3)
    early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 4, verbose = 1)

    #directory for tensorboard to save evnts
    log_dir= modelsDirectory + "logs/fit/" + ModelName + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    os.makedirs(log_dir)

    print("TensorBoard Folder for this Execution",log_dir)#creating TensorBoard call back,this will write all events to given folder
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

    history = tf.keras.callbacks.History()
    callbacks_list = [reduce_lr, early_stop, history, tensorboard_callback, checkpoint]
    return callbacks_list

def Build_BaseModel():
    image_input = tf.keras.layers.Input(shape=(7,7,512))
    question_input = tf.keras.layers.Input(shape=(question_vector_train.shape[1],))

    image_conv_layer1 = tf.keras.layers.Conv2D(filters = 4096, kernel_size = 7 , strides = 1, padding = "valid", activation = 'relu',
                                               kernel_initializer = tf.keras.initializers.he_normal(seed=45))(image_input)

    image_flatten = tf.keras.layers.Flatten()(image_conv_layer1)

    image_dense_1 = tf.keras.layers.Dense(4096, activation = tf.nn.relu, 
                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=54))(image_flatten)
    
    image_dense_2 = tf.keras.layers.Dense(1024, activation = tf.nn.relu, 
                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=32))(image_dense_1)


    # Input 2 Pathway
    question_emb = tf.keras.layers.Embedding(input_dim = len(tokenizer.word_index) + 1, output_dim = 300 ,name = "Embedding_Layer",
                                             embeddings_initializer = tf.keras.initializers.RandomNormal(mean=0, stddev=1, seed=23))(question_input)

    question_lstm = tf.keras.layers.LSTM(1024, 
                                         kernel_initializer = tf.keras.initializers.glorot_uniform(seed=26),
                                         recurrent_initializer = tf.keras.initializers.orthogonal(seed=54),
                                         bias_initializer=tf.keras.initializers.zeros())(question_emb)

    question_flatten = tf.keras.layers.Flatten(name="Flatten_lstm")(question_lstm)

    
    image_question = tf.keras.layers.Multiply()([image_dense_2, question_flatten])


    image_question_dense_1 = tf.keras.layers.Dense(1000, activation = tf.nn.relu,
                                                    kernel_initializer = tf.keras.initializers.he_uniform(seed=19))(image_question)
    
    image_question_dense_2 = tf.keras.layers.Dense(1000, activation = tf.nn.relu, 
                                                   kernel_initializer = tf.keras.initializers.he_uniform(seed=28))(image_question_dense_1)

    output = tf.keras.layers.Dense(len(ans_vocab), activation=tf.nn.softmax, 
                                   kernel_initializer = tf.keras.initializers.glorot_normal(seed=19))(image_question_dense_2)

    # Create Model
    model = tf.keras.models.Model(inputs = [image_input, question_input], outputs = output)
    # Compile
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model'''
# Out:
# 'def callBacksList():\n    """\n    returns list of callback\'s\n    """\n    filepath = modelsDirectory + ModelName + "/best.hdf5"\n    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = filepath, monitor = \'val_accuracy\', verbose = 1, save_best_only = True, mode = \'auto\')\n    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = \'val_accuracy\', patience = 3)\n    early_stop = tf.keras.callbacks.EarlyStopping(monitor = \'val_accuracy\', patience = 4, verbose = 1)\n\n    #directory for tensorboard to save evnts\n    log_dir= modelsDirectory + "logs/fit/" + ModelName + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")\n    os.makedirs(log_dir)\n\n    print("TensorBoard Folder for this Execution",log_dir)#creating TensorBoard call back,this will write all events to given folder\n    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)\n\n    history = tf.keras.callbacks.History()\n    callbacks_list = [reduce_lr, early_stop, history, tensorboard_callback, checkpoint]\n    return callbacks_list\n\ndef Build_BaseModel():\n    image_input = tf.keras.layers.Input(shape=(7,7,512))\n    question_input = tf.keras.layers.Input(shape=(question_vector_train.shape[1],))\n\n    image_conv_layer1 = tf.keras.layers.Conv2D(filters = 4096, kernel_size = 7 , strides = 1, padding = "valid", activation = \'relu\',\n                                               kernel_initializer = tf.keras.initializers.he_normal(seed=45))(image_input)\n\n    image_flatten = tf.keras.layers.Flatten()(image_conv_layer1)\n\n    image_dense_1 = tf.keras.layers.Dense(4096, activation = tf.nn.relu, \n                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=54))(image_flatten)\n    \n    image_dense_2 = tf.keras.layers.Dense(1024, activation = tf.nn.relu, \n                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=32))(image_dense_1)\n\n\n    # Input 2 Pathway\n    question_emb = tf.keras.layers.Embedding(input_dim = len(tokenizer.word_index) + 1, output_dim = 300 ,name = "Embedding_Layer",\n                                             embeddings_initializer = tf.keras.initializers.RandomNormal(mean=0, stddev=1, seed=23))(question_input)\n\n    question_lstm = tf.keras.layers.LSTM(1024, \n                                         kernel_initializer = tf.keras.initializers.glorot_uniform(seed=26),\n                                         recurrent_initializer = tf.keras.initializers.orthogonal(seed=54),\n                                         bias_initializer=tf.keras.initializers.zeros())(question_emb)\n\n    question_flatten = tf.keras.layers.Flatten(name="Flatten_lstm")(question_lstm)\n\n    \n    image_question = tf.keras.layers.Multiply()([image_dense_2, question_flatten])\n\n\n    image_question_dense_1 = tf.keras.layers.Dense(1000, activation = tf.nn.relu,\n                                                    kernel_initializer = tf.keras.initializers.he_uniform(seed=19))(image_question)\n    \n    image_question_dense_2 = tf.keras.layers.Dense(1000, activation = tf.nn.relu, \n                                                   kernel_initializer = tf.keras.initializers.he_uniform(seed=28))(image_question_dense_1)\n\n    output = tf.keras.layers.Dense(len(ans_vocab), activation=tf.nn.softmax, \n                                   kernel_initializer = tf.keras.initializers.glorot_normal(seed=19))(image_question_dense_2)\n\n    # Create Model\n    model = tf.keras.models.Model(inputs = [image_input, question_input], outputs = output)\n    # Compile\n    model.compile(optimizer = \'adam\', loss = \'categorical_crossentropy\', metrics = [\'accuracy\'])\n    return model'

# %%
def callBacksList():
    """
    returns list of callback's
    """
    filepath = modelsDirectory + ModelName + "/best.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = filepath, monitor = 'val_accuracy', verbose = 1, save_best_only = True, mode = 'auto')
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', patience = 3)
    early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 4, verbose = 1)

    #directory for tensorboard to save evnts
    log_dir= modelsDirectory + "logs/fit/" + ModelName + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    os.makedirs(log_dir)

    print("TensorBoard Folder for this Execution",log_dir)#creating TensorBoard call back,this will write all events to given folder
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

    history = tf.keras.callbacks.History()
    callbacks_list = [reduce_lr, early_stop, history, tensorboard_callback, checkpoint]
    return callbacks_list

def Build_BaseModel():
    #image_input = tf.keras.layers.Input(shape=(7,7,512))
    image_input = tf.keras.layers.Input(shape=(10,))
    print("image input shape")
    print(image_input.shape)
    question_input = tf.keras.layers.Input(shape=(question_vector_train.shape[0],))
    print("question input shape")
    print(question_input.shape)
    

    #image_conv_layer1 = tf.keras.layers.Conv2D(filters = 4096, kernel_size = 7 , strides = 1, padding = "valid",input_shape='image_input', activation = 'relu',
                                              #kernel_initializer = tf.keras.initializers.he_normal(seed=45))(image_input)

    #image_flatten = tf.keras.layers.Flatten()(image_conv_layer1)

    image_dense_1 = tf.keras.layers.Dense(64, activation = tf.nn.relu, 
                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=54))(image_input)
                                         
    print("image dense 1 shape")
    print(image_dense_1.shape)                                      
    
    #image_dense_2 = tf.keras.layers.Dense(1024, activation = tf.nn.relu, 
                                          #kernel_initializer = tf.keras.initializers.he_uniform(seed=32))(image_dense_1)
    img_res = tf.reshape(image_dense_1,shape=[-1,4096]) 
    print("image dense 2 shape")
    #print(image_dense_2.shape)

    # Input 2 Pathway
    question_emb = tf.keras.layers.Embedding(input_dim = len(tokenizer.word_index) + 1, output_dim = 300 ,name = "Embedding_Layer",
                                             embeddings_initializer = tf.keras.initializers.RandomNormal(mean=0, stddev=1, seed=23))(question_input)
    print("question emb shape")
    print(question_emb.shape)                                         

    question_lstm = tf.keras.layers.LSTM(1024, 
                                         kernel_initializer = tf.keras.initializers.glorot_uniform(seed=26),
                                         recurrent_initializer = tf.keras.initializers.orthogonal(seed=54),
                                         bias_initializer=tf.keras.initializers.zeros())(question_emb)
                                         
    print("question lstm shape")
    print(question_lstm.shape)
    question_flatten = tf.keras.layers.Flatten(name="Flatten_lstm")(question_lstm)
    
    print("question_flatten shape")
    print(question_flatten.shape)
    ques_res = tf.reshape(question_flatten,shape=[-1,4096]) 
    #image_question = tf.keras.layers.Multiply()([img_res, ques_res],1)
    image_question = tf.concat([image_dense_1,question_flatten],axis=1)
    print("image_question shape")
    print(image_question.shape)

    #image_question_dense_1 = tf.keras.layers.Dense(1024, activation = tf.nn.relu,
                                                   # kernel_initializer = tf.keras.initializers.he_uniform(seed=19))(image_question)
    print("image question shape")
    #print(image_question_dense_1.shape) 
    #image_question_flat = tf.reshape(image_question,shape=[-1,4096]) 
    '''print("image_question_flat shape")
    print(image_question_flat.shape)'''                                             
    
    image_question_dense_2 = tf.keras.layers.Dense(1024, activation = tf.nn.relu, 
                                                   kernel_initializer = tf.keras.initializers.he_uniform(seed=28))(image_question)

    print("image_question_dense_2.shape") 
    print(image_question_dense_2.shape)                                               

    output = tf.keras.layers.Dense(len(ans_vocab), activation=tf.nn.softmax, 
                                   kernel_initializer = tf.keras.initializers.glorot_normal(seed=19))(image_question_dense_2)
    print("output shape")
    print(output[0].shape)

    # Create Model
    modelc = tf.keras.models.Model(inputs = [image_input, question_input], outputs = output)
   # modelc = tf.keras.models.Model(inputs = [image_input, question_input], logits = output)
  
    # Compile
    modelc.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return modelc

# %%
l2_alpha = 0.001
ModelName = "BaselineModel"
modelb = Build_BaseModel()
modelb.summary()
model_vqa = modelb.save('VQAs_MODEL_WEIGHTS.hdf5')
mode_save = modelb.save('my_vqas_model')

#model.fit(train_ddata, epochs = 1, callbacks = callBacksList())
#model.fit(train_ddata, epochs = 1, validation_data = dataset_val, callbacks = callBacksList())
# Out:
# image input shape
# (None, 10)
# question input shape
# (None, 187)
# image dense 1 shape
# (None, 64)
# image dense 2 shape
# question emb shape
# (None, 187, 300)
# question lstm shape
# (None, 1024)
# question_flatten shape
# (None, 1024)
# image_question shape
# (None, 1088)
# image question shape
# image_question_dense_2.shape
# (None, 1024)
# output shape
# (102,)
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 187)]        0           []
#
#  Embedding_Layer (Embedding)    (None, 187, 300)     106800      ['input_18[0][0]']
#
#  input_17 (InputLayer)          [(None, 10)]         0           []
#
#  lstm_8 (LSTM)                  (None, 1024)         5427200     ['Embedding_Layer[0][0]']
#
#  dense_28 (Dense)               (None, 64)           704         ['input_17[0][0]']
#
#  Flatten_lstm (Flatten)         (None, 1024)         0           ['lstm_8[0][0]']
#
#  tf.concat_8 (TFOpLambda)       (None, 1088)         0           ['dense_28[0][0]',
#                                                                   'Flatten_lstm[0][0]']
#
#  dense_29 (Dense)               (None, 1024)         1115136     ['tf.concat_8[0][0]']
#
#  dense_30 (Dense)               (None, 102)          104550      ['dense_29[0][0]']
#
# ==================================================================================================
# Total params: 6,754,390
# Trainable params: 6,754,390
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:absl:Found untraced functions such as lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_vqas_model/assets
# INFO:tensorflow:Assets written to: my_vqas_model/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f0db7bc6850> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
#modelb.fit(dataset_train, epochs = 20, callbacks = callBacksList())
modelb.fit(dataset_train, epochs = 20, validation_data = dataset_val, callbacks = callBacksList())
#model.fit(dataset_train, epochs = 2, validation_data = dataset_val, callbacks = callBacksList())
# Out:
# TensorBoard Folder for this Execution Models/logs/fit/BaselineModel/20220523-124212
# Epoch 1/20
# 1/3 [=========>....................] - ETA: 3:28 - loss: 4.7314 - accuracy: 0.0156
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to Models/BaselineModel/best.hdf5
# 3/3 [==============================] - 107s 1s/step - loss: 4.7287 - accuracy: 0.1283 - val_loss: 1.9464 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/20
# 3/3 [==============================] - ETA: 0s - loss: 4.3721 - accuracy: 0.0963
# Epoch 2: val_accuracy improved from 0.00000 to 0.14894, saving model to Models/BaselineModel/best.hdf5
# 3/3 [==============================] - 2s 863ms/step - loss: 4.3721 - accuracy: 0.0963 - val_loss: 1.1351 - val_accuracy: 0.1489 - lr: 0.0010
# Epoch 3/20
# 3/3 [==============================] - ETA: 0s - loss: 3.8299 - accuracy: 0.1818
# Epoch 3: val_accuracy improved from 0.14894 to 0.17021, saving model to Models/BaselineModel/best.hdf5
# 3/3 [==============================] - 2s 824ms/step - loss: 3.8299 - accuracy: 0.1818 - val_loss: 0.9956 - val_accuracy: 0.1702 - lr: 0.0010
# Epoch 4/20
# 3/3 [==============================] - ETA: 0s - loss: 3.8379 - accuracy: 0.2032
# Epoch 4: val_accuracy did not improve from 0.17021
# 3/3 [==============================] - 1s 665ms/step - loss: 3.8379 - accuracy: 0.2032 - val_loss: 1.1347 - val_accuracy: 0.1489 - lr: 0.0010
# Epoch 5/20
# 3/3 [==============================] - ETA: 0s - loss: 3.7990 - accuracy: 0.1765
# Epoch 5: val_accuracy did not improve from 0.17021
# 3/3 [==============================] - 1s 666ms/step - loss: 3.7990 - accuracy: 0.1765 - val_loss: 1.1702 - val_accuracy: 0.1489 - lr: 0.0010
# Epoch 6/20
# 3/3 [==============================] - ETA: 0s - loss: 3.7695 - accuracy: 0.1818
# Epoch 6: val_accuracy did not improve from 0.17021
# 3/3 [==============================] - 1s 674ms/step - loss: 3.7695 - accuracy: 0.1818 - val_loss: 1.0646 - val_accuracy: 0.1702 - lr: 0.0010
# Epoch 7/20
# 3/3 [==============================] - ETA: 0s - loss: 3.7350 - accuracy: 0.2032
# Epoch 7: val_accuracy did not improve from 0.17021
# 3/3 [==============================] - 1s 668ms/step - loss: 3.7350 - accuracy: 0.2032 - val_loss: 1.0557 - val_accuracy: 0.1702 - lr: 1.0000e-04
# Epoch 7: early stopping

# %%
recons_model = tf.keras.models.load_model('/content/drive/MyDrive/newresults/my_vqas_model')

# %%
recons_model.load_weights('/content/drive/MyDrive/newresults/VQAs_MODEL_WEIGHTS.hdf5')
#recons_model.evaluate(dataset_val)

# %%
'''%load_ext tensorboard
# %tensorboard --logdir Models/logs/fit/BaselineModel'''
# Out:
# '%load_ext tensorboard\n%tensorboard --logdir Models/logs/fit/BaselineModel'

# %% [markdown]
# **TESTING**

# %%
#model.load_weights(modelsDirectory + ModelName + "/best.hdf5")
test_idx = np.random.randint(len(X_val), size = 3)
model_vgg = Alex_Top()
k = 5

for idx in test_idx:
    test_image_id = X_val['image_id'].values[idx]
    test_question = X_val['question'].values[idx]
    actual_answer = X_val['multiple_choice_answer'].values[idx]
    test_image_path = imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (test_image_id)

    test_image_features = model_vgg(tf.expand_dims(load_image(test_image_path)[0], 0))
    test_question_features = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([test_question]),padding='post',
                                                                           maxlen=question_vector_train.shape[0])
    y_pred = recons_model.predict([test_image_features,test_question_features])

    class_indices = tf.math.top_k(y_pred,k=k).indices.numpy()
    percentages = tf.math.top_k(y_pred,k=k).values.numpy()[0] * 100
    predictions = []
    for idx,i in enumerate(class_indices[0]):
        classes = np.zeros((1,1000))
        classes[0][i] = 1
        predictions.append((label_encoder.inverse_transform(classes)[0],percentages[idx]))

    img=mpimg.imread(test_image_path)
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()

    print("Question :", test_question.replace("<start> ","").replace(" <end>",""))
    print("Actual Answer: ", actual_answer)
    print("Top Predicted answers: ",predictions)
    print("*"*150)
# Out:
# Toy ResNet model for CIFAR10
# Layers generated for model
# More information about the model
# Model: "toy_resnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_21 (Conv2D)             (None, 222, 222, 32  896         ['img[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 220, 220, 64  18496       ['conv2d_21[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 73, 73, 64)  0           ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 73, 73, 64)   36928       ['max_pooling2d_3[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 73, 73, 64)   36928       ['conv2d_23[0][0]']
#
#  add_6 (Add)                    (None, 73, 73, 64)   0           ['conv2d_24[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 73, 73, 64)   36928       ['add_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 73, 73, 64)   36928       ['conv2d_25[0][0]']
#
#  add_7 (Add)                    (None, 73, 73, 64)   0           ['conv2d_26[0][0]',
#                                                                   'add_6[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 71, 71, 64)   36928       ['add_7[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 64)          0           ['conv2d_27[0][0]']
#  obalAveragePooling2D)
#
#  dense_31 (Dense)               (None, 256)          16640       ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (None, 10)           2570        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 223,242
# Trainable params: 223,242
# Non-trainable params: 0
# __________________________________________________________________________________________________
# img after channels shape
# (446, 640, 3)
# img after resize shape
# (224, 224, 3)
# Question : what quality is the photo?
# Actual Answer:  good
# Top Predicted answers:  [('1', 1.8764555), ('marble', 1.7754207), ('nothing', 1.7624819), ('talbot', 1.6445818), ('calico', 1.6265051)]
# ******************************************************************************************************************************************************
# img after channels shape
# (640, 480, 3)
# img after resize shape
# (224, 224, 3)
# Question : what is the boy standing on?
# Actual Answer:  ground
# Top Predicted answers:  [('1', 1.8736137), ('marble', 1.7770469), ('nothing', 1.7632309), ('talbot', 1.6448563), ('calico', 1.6247876)]
# ******************************************************************************************************************************************************
# img after channels shape
# (481, 640, 3)
# img after resize shape
# (224, 224, 3)
# Question : what is hanging off the table?
# Actual Answer:  cane
# Top Predicted answers:  [('1', 1.8914945), ('marble', 1.7700145), ('nothing', 1.7613182), ('talbot', 1.6454527), ('calico', 1.6382071)]
# ******************************************************************************************************************************************************
